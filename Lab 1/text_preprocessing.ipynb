# %% [markdown]
# ### Ex 1
#
# Download it through python (inside the code, so you don't have to upload the file too when you send the solution for this exercise) with urlopen() from module urllib and read the entire text in one single string. If the download takes too much time at each running, download the file, but leave the former instructions in a comment (to show that you know how to access an online file)

# %%
import urllib.request

url = "https://www.gutenberg.org/cache/epub/73288/pg73288.txt"

response = urllib.request.urlopen(url)
text = response.read().decode("utf-8") 
print("Text downloaded successfully!")
# Out:
# Text downloaded successfully!

# %% [markdown]
# ### Ex 2
#
# Remove the header (keep only the text starting from the title)

# %%
header_treshold = "*** START OF THE PROJECT GUTENBERG EBOOK THE SURVIVORS ***"
title_index = text.find(header_treshold)
text_without_header = text[title_index+len(header_treshold):]

# %% [markdown]
# ### Ex 3
#
# Print the number of sentences in the text. Print the average length (number of words) of a sentence.

# %%
import re

sentences = re.split(r'[.!?]', text_without_header)

sentences = [sentence for sentence in sentences if sentence.strip()]

num_sentences = len(sentences)

avg_sentence_length = sum(len(sentence.split()) for sentence in sentences) / num_sentences

print(f"Number of sentences: {num_sentences}")
print(f"Average length of a sentence: {avg_sentence_length} words")
# Out:
# Number of sentences: 596
# Average length of a sentence: 13.046979865771812 words

# %% [markdown]
# ### Ex 4
#
# Find the collocations in the text (bigram and trigram). Use the nltk.collocations module You will print them only once not each time they appear.

# %%
import nltk
from nltk.collocations import BigramCollocationFinder, TrigramCollocationFinder
from nltk.metrics import BigramAssocMeasures, TrigramAssocMeasures

nltk.download('punkt')

tokens = nltk.word_tokenize(text_without_header)

collocations_treshold = 10

bigram_finder = BigramCollocationFinder.from_words(tokens)
bigram_collocations = set(bigram_finder.nbest(BigramAssocMeasures.likelihood_ratio, collocations_treshold))

trigram_finder = TrigramCollocationFinder.from_words(tokens)
trigram_collocations = set(trigram_finder.nbest(TrigramAssocMeasures.likelihood_ratio, collocations_treshold))

print("Bigram Collocations:")
for bigram in bigram_collocations:
    print(bigram)

print("\nTrigram Collocations:")
for trigram in trigram_collocations:
    print(trigram)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\chimi\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Bigram Collocations:
# ('Gutenberg™', 'electronic')
# ('Project', 'Gutenberg')
# ('United', 'States')
# ('electronic', 'works')
# ('Gutenberg', 'Literary')
# ('Project', 'Gutenberg™')
# ('Literary', 'Archive')
# ('!', "''")
# ('.', '``')
# ('*', '*')
#
# Trigram Collocations:
# ('full', 'Project', 'Gutenberg™')
# ('Project', 'Gutenberg™', 'work')
# ('Project', 'Gutenberg™', 'trademark')
# ('the', 'Project', 'Gutenberg™')
# ('Project', 'Gutenberg™', 'eBooks')
# ('of', 'Project', 'Gutenberg™')
# ('Project', 'Gutenberg™', 'works')
# ('Project', 'Gutenberg™', 'electronic')
# ('Project', 'Gutenberg™', 'License')
# ('*', '*', '*')

# %% [markdown]
# ### Ex 5
# Create a list of all the words (in lower case) from the text, without the punctuation.

# %%
import string

text_without_punctuation = text_without_header.translate(str.maketrans('', '', string.punctuation)).lower()

words = nltk.word_tokenize(text_without_punctuation)
print(words)
# Out:
# ['the', 'survivors', 'by', 't', 'd', 'hamm', 'illustrated', 'by', 'douglas', 'step', 'by', 'gruelling', 'step', 'the', 'four', 'of', 'them', 'slogged', 'their', 'way', 'toward', 'a', 'perilous', 'safety', 'it', 'was', 'a', 'magnificent', 'display', 'of', 'the', 'will', 'for', 'survival', 'the', 'only', 'question', 'was', 'whose', 'survival', 'transcribers', 'note', 'this', 'etext', 'was', 'produced', 'from', 'amazing', 'stories', 'august', '1961', 'extensive', 'research', 'did', 'not', 'uncover', 'any', 'evidence', 'that', 'the', 'us', 'copyright', 'on', 'this', 'publication', 'was', 'renewed', 'there', 'were', 'only', 'four', 'of', 'them', 'now', 'soames', 'and', 'rutherford', 'had', 'literally', 'gone', 'down', 'with', 'the', 'ship', 'in', 'a', 'roar', 'of', 'cascading', 'rock', 'and', 'sand', 'out', 'of', 'fifty', 'square', 'miles', 'of', 'the', 'martian', 'plateau', 'they', 'had', 'been', 'unlucky', 'enough', 'to', 'sit', 'down', 'on', 'the', 'eggshell', 'thin', 'roof', 'of', 'a', 'sector', 'honeycombed', 'with', 'caves', 'scant', 'moments', 'after', 'the', 'exploring', 'party', 'had', 'disembarked', 'soames', 'comments', 'on', 'their', 'resemblance', 'to', 'a', 'sunday', 'school', 'picnic', 'were', 'suddenly', 'broken', 'off', 'by', 'a', 'cacophonous', 'medley', 'of', 'yells', 'the', 'rolling', 'thunder', 'of', 'sliding', 'rock', 'and', 'over', 'all', 'the', 'agonized', 'metallic', 'shrieking', 'of', 'tortured', 'metal', 'as', 'the', 'ship', 'fell', 'crushed', 'and', 'twisted', 'there', 'came', 'a', 'final', 'tremendous', 'roar', 'as', 'the', 'fuel', 'tanks', 'blew', 'the', 'ground', 'heaved', 'convulsively', 'and', 'shuddered', 'into', 'silence', 'stunned', 'and', 'deafened', 'bradford', 'canham', 'palmer', 'and', 'rodriguez', 'pulled', 'themselves', 'to', 'their', 'feet', 'staring', 'dazedly', 'at', 'the', 'towering', 'column', 'of', 'dust', 'hanging', 'like', 'a', 'malevolent', 'genie', 'over', 'the', 'halfmile', 'wide', 'chasm', 'palmer', 'white', 'with', 'shock', 'lunged', 'forward', 'turning', 'indignantly', 'as', 'bradfords', 'arm', 'jerked', 'him', 'back', 'soamesand', 'rutherford', 'he', 'stuttered', 'weve', 'got', 'to', 'do', 'something', 'bradfords', 'lip', 'twisted', 'mirthlessly', 'whatre', 'you', 'going', 'to', 'dojump', 'in', 'after', 'them', 'if', 'there', 'was', 'anything', 'left', 'of', 'them', 'the', 'fuel', 'tanks', 'took', 'care', 'of', 'it', 'theyre', 'gonewere', 'here', 'and', 'wed', 'better', 'start', 'figuring', 'out', 'what', 'were', 'going', 'to', 'do', 'about', 'it', 'the', 'four', 'of', 'them', 'looked', 'at', 'each', 'other', 'silently', 'they', 'knew', 'as', 'well', 'as', 'he', 'what', 'they', 'faced', 'theirs', 'had', 'been', 'the', 'task', 'of', 'setting', 'up', 'a', 'temporary', 'exploring', 'base', 'till', 'the', 'supply', 'ship', 'arrived', 'in', 'three', 'monthswith', 'luck', 'supplies', 'for', 'six', 'months', 'and', 'all', 'their', 'equipment', 'except', 'their', 'emergency', 'rations', 'had', 'gone', 'down', 'with', 'the', 'ship', 'no', 'hope', 'thereas', 'well', 'explore', 'the', 'grand', 'canyon', 'with', 'a', 'teaspoon', 'as', 'to', 'try', 'to', 'salvage', 'anything', 'under', 'that', 'million', 'tons', 'of', 'rock', 'compressed', 'food', 'they', 'had', 'two', 'weeks', 'supply', 'per', 'man', 'their', 'extra', 'oxygen', 'tanks', 'an', 'extra', 'battery', 'apiece', 'for', 'the', 'suit', 'heaters', 'water', 'would', 'be', 'their', 'worst', 'problem', 'bradford', 'looked', 'at', 'the', 'miles', 'of', 'barren', 'reddish', 'wasteland', 'and', 'shrugged', 'fatalistically', 'if', 'theres', 'any', 'water', 'at', 'all', 'it', 'will', 'be', 'at', 'the', 'polar', 'cap', 'we', 'might', 'as', 'well', 'get', 'goingweve', 'got', 'a', 'long', 'hike', 'palmer', 'grimaced', 'wryly', 'forward', 'you', 'eagle', 'scouts', 'we', 'can', 'get', 'our', 'merit', 'badges', 'easy', 'yeah', 'we', 'can', 'get', 'them', 'from', 'santa', 'claus', 'at', 'the', 'pole', 'rodriguez', 'made', 'a', 'valiant', 'attemp ...

# %% [markdown]
# ### Ex 6
# Print the first N most frequent words (alphanumeric strings) together with their number of appearances.

# %%
from collections import Counter

word_counts = Counter(words)

N = 10

most_common_words = word_counts.most_common(N)

for word, count in most_common_words:
    print(f"{word}: {count}")
# Out:
# the: 452
# of: 242
# a: 180
# and: 169
# to: 161
# in: 113
# with: 103
# you: 95
# project: 85
# or: 81

# %% [markdown]
# ### Ex 7
# Remove stopwords and assign the result to variable lws

# %%
from nltk.corpus import stopwords

nltk.download('stopwords')

stopwords_set = set(stopwords.words('english'))

lws = [word for word in words if word not in stopwords_set]

N = 10

print(lws[:N])
# Out:
# ['survivors', 'hamm', 'illustrated', 'douglas', 'step', 'gruelling', 'step', 'four', 'slogged', 'way']
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\chimi\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ### Ex 8
# Apply stemming (Porter) on the list of words (lws). Print the first 200 words. Do you see any words that don't appear in the dictionary?

# %%
from nltk.stem import PorterStemmer

stemmer = PorterStemmer()

stemmed_words = list(set([stemmer.stem(word) for word in lws]))

print(stemmed_words[:200])
# Out:
# ['destin', 'left', 'alter', 'sway', 'around', 'good', '1e2', 'rain', 'hut', 'visitor', 'inquisit', 'goe', 'holder', 'exist', 'consequenti', 'liter', '646221541', 'restrict', 'im', 'daze', 'abid', 'pad', 'dimli', 'absent', 'titl', 'midair', 'intermin', 'unus', '1', 'probabl', 'plant', 'forg', 'wateri', 'martian', 'dioxid', 'text', 'guardian', 'bottl', 'compass', 'year', 'full', 'metal', 'magnific', 'wheez', 'hang', 'soam', 'shout', 'today', 'forest', 'sullenli', 'brother', 'practic', 'alonei', 'godi', 'darkli', 'ought', 'carbon', 'huddl', 'thought', 'silent', 'slowli', 'hart', 'hope', 'wane', 'compli', 'kid', 'step', 'medley', 'flower', 'error', 'nake', 'gutenberg', '1e5', 'groan', 'squirm', 'beyond', 'mile', '1e9', 'iron', 'undeniablygreen', 'trot', 'wwwgutenbergorglicens', 'vein', 'encircl', 'go', 'directli', 'downi', 'way', 'name', 'muscl', 'strode', 'warmso', 'seem', 'wri', 'fifteen', 'field', 'jettison', 'face', 'hover', 'anybodi', 'pile', 'earphon', 'crumb', 'warmblood', 'kill', 'present', 'gone', 'atmospher', 'haunt', 'slightli', 'grow', 'stiff', 'twig', 'employe', 'onto', 'couldnt', 'reluctantli', 'agreement', 'ground', 'disk', 'sever', 'trademark', 'perspir', 'watergrass', 'fortun', 'spacesuit', 'darktoward', 'pale', 'shock', 'sickeningli', 'three', 'even', 'inner', '84116', 'oxygenstarv', 'impli', 'perform', 'acknowledg', 'beast', 'stunt', 'side', 'night', 'librari', 'mar', 'mr', 'tank', 'remark', 'wait', 'bush', 'grand', 'regist', 'sacrific', 'cover', 'treatment', 'entiti', 'instinct', 'toward', 'thin', 'need', 'behinddu', 'save', 'clumsili', 'stumbl', 'anoth', 'horizon', 'unenforc', 'knee', 'open', '801', 'nativ', 'tall', 'triumph', 'caressingli', 'astonish', 'digniti', 'reflect', 'growth', 'seal', 'stark', 'unend', 'tap', 'fieri', 'sank', 'unprotect', 'helmet', 'far', 'hit', 'behind', 'uncov', 'childish', 'identif', 'void', 'kingdom', 'possess', 'littl', 'thingrodriguez', 'learn', 'ensur', 'hour', 'swollen']

# %% [markdown]
# ### Ex 9
# Print a table of three columns (of size N, where N is the maximum length for the words in the text). The columns will be separated with the character "|". The head of the table will be:
#
# Porter    |Lancaster |Snowball
#
# The table will contain only the words that give different stemming results for the three stemmers (for example, suppose that we have both "runs" and "being" inside the text. The word "runs" should not appear in the list, as all three results are "run"; however "being" should appear in the table). The stemming result for the word for each stemmer will appear in the table according to the head of the table. The table will contain the results for the first NW words from the text (the number of rows will obviously be less than NW, as not all words match the requirements). For example, NW=500. Try to print only distinct results inside the table (for example, if a word has two occurnces inside the text, and matches the requirments for appearing in the table, it should have only one corresponding row).

# %%
from nltk.stem import PorterStemmer, LancasterStemmer, SnowballStemmer

porter_stemmer = PorterStemmer()
lancaster_stemmer = LancasterStemmer()
snowball_stemmer = SnowballStemmer('english')

table = []
NW = 500


for word in words[:NW]:

    porter_stem = porter_stemmer.stem(word)
    lancaster_stem = lancaster_stemmer.stem(word)
    snowball_stem = snowball_stemmer.stem(word)
    
    # Check if the stemming results are different for each stemmer
    if porter_stem != lancaster_stem != snowball_stem:
        # Add the word and its stemming results to the table
        table.append([porter_stem, lancaster_stem, snowball_stem])

print("Porter    |Lancaster |Snowball")
for row in table:
    print(f"{row[0]:<10}|{row[1]:<10}|{row[2]:<10}")
# Out:
# Porter    |Lancaster |Snowball
# survivor  |surv      |survivor
# hamm      |ham       |hamm
# illustr   |illust    |illustr
# gruell    |gruel     |gruell
# safeti    |saf       |safeti
# magnific  |magn      |magnific
# will      |wil       |will
# surviv    |surv      |surviv
# onli      |on        |onli
# question  |quest     |question
# whose     |whos      |whose
# surviv    |surv      |surviv
# note      |not       |note
# stori     |story     |stori
# extens    |extend    |extens
# ani       |any       |ani
# public    |publ      |public
# there     |ther      |there
# were      |wer       |were
# onli      |on        |onli
# liter     |lit       |liter
# gone      |gon       |gone
# fifti     |fifty     |fifti
# squar     |squ       |squar
# mile      |mil       |mile
# martian   |mart      |martian
# unlucki   |unlucky   |unlucki
# sector    |sect      |sector
# cave      |cav       |cave
# moment    |mom       |moment
# after     |aft       |after
# explor    |expl      |explor
# parti     |party     |parti
# comment   |com       |comment
# picnic    |picn      |picnic
# were      |wer       |were
# suddenli  |sud       |sudden
# broken    |brok      |broken
# yell      |yel       |yell
# roll      |rol       |roll
# thunder   |thund     |thunder
# slide     |slid      |slide
# over      |ov        |over
# all       |al        |all
# shriek    |shrieking |shriek
# tortur    |tort      |tortur
# metal     |met       |metal
# fell      |fel       |fell
# there     |ther      |there
# came      |cam       |came
# final     |fin       |final
# shudder   |shud      |shudder
# silenc    |sil       |silenc
# deafen    |deaf      |deafen
# palmer    |palm      |palmer
# pull      |pul       |pull
# stare     |star      |stare
# dazedli   |daz       |daze
# tower     |tow       |tower
# like      |lik       |like
# geni      |geny      |geni
# over      |ov        |over
# wide      |wid       |wide
# palmer    |palm      |palmer
# white     |whit      |white
# stutter   |stut      |stutter
# weve      |wev       |weve
# whatr     |what      |whatr
# go        |going     |go
# after     |aft       |after
# there     |ther      |there
# care      |car       |care
# gonewer   |gonew     |gonewer
# here      |her       |here
# better    |bet       |better
# figur     |fig       |figur
# were      |wer       |were
# go        |going     |go
# other     |oth       |other
# silent    |sil       |silent
# well      |wel       |well
# face      |fac       |face
# temporari |temp      |temporari
# explor    |expl      |explor
# base      |bas       |base
# till      |til       |till
# suppli    |supply    |suppli
# arriv     |ar        |arriv
# monthswith|monthswi  |monthswith
# suppli    |supply    |suppli
# all       |al        |all
# except    |exceiv    |except
# ration    |rat       |ration
# gone      |gon       |gone
# hope      |hop       |hope
# well      |wel       |well
# explor    |expl      |explor
# tri       |try       |tri
# salvag    |salv      |salvag
# under     |und       |under
# million   |mil       |million
# suppli    |supply    |suppli
# extra     |extr      |extra
# oxygen    |oxyg      |oxygen
# extra     |extr      |extra
# batteri   |battery   |batteri
# heater    |heat      |heater
# water     |wat       |water
# mile      |mil       |mile
# barren    |bar       |barren
# reddish   |red       |reddish
# shrug     |shrugged  |shrug
# fatalist  |fat       |fatalist
# there     |ther      |there
# ani       |any       |ani
# water     |wat       |water
# all       |al        |all
# will      |wil       |will
# polar     |pol       |polar
# well      |wel       |well
# hike      |hik       |hike
# palmer    |palm      |palmer
# wryli     |wry       |wryli
# easi      |easy      |easi
# santa     |sant      |santa
# clau      |cla       |claus
# pole      |pol       |pole
# made      |mad       |made
# valiant   |valy      |valiant
# usual     |us        |usual
# humor     |hum       |humor
# pile      |pil       |pile
# small     |smal      |small
# white     |whit      |white
# feder     |fed       |feder
# nation    |nat       |nation
# cover     |cov       |cover
# place     |plac      |place
# note      |not       |note
# indic     |ind       |indic

# %% [markdown]
# ### Ex 10
# Print a table of two columns, simillar to the one above, that will compare the results of stemming and lemmatization. The head of the table will contain the values: "Snowball" and "WordNetLemmatizer". The table must contain only words that give different results in the process of stemming and lemmatization (for example, the word "running"). The table will contain the results for the first NW words from the text (the number of rows will obviously be less than NW, as not all words match the requirements). For example, NW=500. Try to print only distinct results inside the table (for example, if a word has two occurnces inside the text, and matches the requirments for appearing in the table, it should have only one corresponding row).

# %%
from nltk.stem import SnowballStemmer
from nltk.stem import WordNetLemmatizer
from tabulate import tabulate

nltk.download('wordnet')

snowball_stemmer = SnowballStemmer("english")
lemmatizer = WordNetLemmatizer()

stemmed_words = []
lemmatized_words = []

for word in tokens[:NW]:
    stemmed_word = snowball_stemmer.stem(word.lower())
    lemmatized_word = lemmatizer.lemmatize(word.lower())
    
    if stemmed_word != lemmatized_word:
        stemmed_words.append(stemmed_word)
        lemmatized_words.append(lemmatized_word)

table_data = list(zip(stemmed_words, lemmatized_words))
table_headers = ["Snowball", "WordNetLemmatizer"]

table = tabulate(table_data, headers=table_headers, tablefmt="grid")
print(table)
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\chimi\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# +------------+---------------------+
# | Snowball   | WordNetLemmatizer   |
# +============+=====================+
# | illustr    | illustrated         |
# +------------+---------------------+
# | dougla     | douglas             |
# +------------+---------------------+
# | gruell     | gruelling           |
# +------------+---------------------+
# | slog       | slogged             |
# +------------+---------------------+
# | peril      | perilous            |
# +------------+---------------------+
# | safeti     | safety              |
# +------------+---------------------+
# | was        | wa                  |
# +------------+---------------------+
# | magnific   | magnificent         |
# +------------+---------------------+
# | surviv     | survival            |
# +------------+---------------------+
# | onli       | only                |
# +------------+---------------------+
# | transcrib  | transcriber         |
# +------------+---------------------+
# | was        | wa                  |
# +------------+---------------------+
# | produc     | produced            |
# +------------+---------------------+
# | amaz       | amazing             |
# +------------+---------------------+
# | stori      | story               |
# +------------+---------------------+
# | extens     | extensive           |
# +------------+---------------------+
# | uncov      | uncover             |
# +------------+---------------------+
# | ani        | any                 |
# +------------+---------------------+
# | evid       | evidence            |
# +------------+---------------------+
# | public     | publication         |
# +------------+---------------------+
# | was        | wa                  |
# +------------+---------------------+
# | renew      | renewed             |
# +------------+---------------------+
# | onli       | only                |
# +------------+---------------------+
# | soam       | soames              |
# +------------+---------------------+
# | liter      | literally           |
# +------------+---------------------+
# | cascad     | cascading           |
# +------------+---------------------+
# | fifti      | fifty               |
# +------------+---------------------+
# | squar      | square              |
# +------------+---------------------+
# | unlucki    | unlucky             |
# +------------+---------------------+
# | egg-shel   | egg-shell           |
# +------------+---------------------+
# | honey-comb | honey-combed        |
# +------------+---------------------+
# | explor     | exploring           |
# +------------+---------------------+
# | parti      | party               |
# +------------+---------------------+
# | disembark  | disembarked         |
# +------------+---------------------+
# | soam       | soames'             |
# +------------+---------------------+
# | resembl    | resemblance         |
# +------------+---------------------+
# | sudden     | suddenly            |
# +------------+---------------------+
# | cacophon   | cacophonous         |
# +------------+---------------------+
# | roll       | rolling             |
# +------------+---------------------+
# | slide      | sliding             |
# +------------+---------------------+
# | agon       | agonized            |
# +------------+---------------------+
# | metal      | metallic            |
# +------------+---------------------+
# | shriek     | shrieking           |
# +------------+---------------------+
# | tortur     | tortured            |
# +------------+---------------------+
# | as         | a                   |
# +------------+---------------------+
# | crush      | crushed             |
# +------------+---------------------+
# | twist      | twisted             |
# +------------+---------------------+
# | tremend    | tremendous          |
# +------------+---------------------+
# | as         | a                   |
# +------------+---------------------+
# | heav       | heaved              |
# +------------+---------------------+
# | convuls    | convulsively        |
# +------------+---------------------+
# | shudder    | shuddered           |
# +------------+---------------------+
# | silenc     | silence             |
# +------------+---------------------+
# | stun       | stunned             |
# +------------+---------------------+
# | deafen     | deafened            |
# +------------+---------------------+
# | pull       | pulled              |
# +------------+---------------------+
# | themselv   | themselves          |
# +------------+---------------------+
# | feet       | foot                |
# +------------+---------------------+
# | stare      | staring             |
# +------------+---------------------+
# | daze       | dazedly             |
# +------------+---------------------+
# | tower      | towering            |
# +------------+---------------------+
# | hang       | hanging             |
# +------------+---------------------+
# | malevol    | malevolent          |
# +------------+---------------------+
# | geni       | genie               |
# +------------+---------------------+
# | half-mil   | half-mile           |
# +------------+---------------------+
# | lung       | lunged              |
# +------------+---------------------+
# | turn       | turning             |
# +------------+---------------------+
# | indign     | indignantly         |
# +------------+---------------------+
# | as         | a                   |
# +------------+---------------------+
# | jerk       | jerked              |
# +------------+---------------------+
# | soam       | soames              |
# +------------+---------------------+
# | stutter    | stuttered           |
# +------------+---------------------+
# | ve         | 've                 |
# +------------+---------------------+
# | someth     | something           |
# +------------+---------------------+
# | twist      | twisted             |
# +------------+---------------------+
# | mirthless  | mirthlessly         |
# +------------+---------------------+
# | re         | 're                 |
# +------------+---------------------+
# | go         | going               |
# +------------+---------------------+
# | was        | wa                  |
# +------------+---------------------+
# | anyth      | anything            |
# +------------+---------------------+
# | re         | 're                 |
# +------------+---------------------+
# | re         | 're                 |
# +------------+---------------------+
# | figur      | figuring            |
# +------------+---------------------+
# | re         | 're                 |
# +------------+---------------------+
# | go         | going               |
# +------------+---------------------+
# | look       | looked              |
# +------------+---------------------+
# | silent     | silently            |
# +------------+---------------------+
# | as         | a                   |
# +------------+---------------------+
# | as         | a                   |
# +------------+---------------------+
# | face       | faced               |
# +------------+---------------------+
# | their      | theirs              |
# +------------+---------------------+
# | set        | setting             |
# +------------+---------------------+
# | temporari  | temporary           |
# +------------+---------------------+
# | explor     | exploring           |
# +------------+---------------------+
# | suppli     | supply              |
# +------------+---------------------+
# | arriv      | arrived             |
# +------------+---------------------+
# | suppli     | supply              |
# +------------+---------------------+
# | equip      | equipment           |
# +------------+---------------------+
# | emerg      | emergency           |
# +------------+---------------------+
# | as         | a                   |
# +------------+---------------------+
# | explor     | explore             |
# +------------+---------------------+
# | as         | a                   |
# +------------+---------------------+
# | tri        | try                 |
# +------------+---------------------+
# | salvag     | salvage             |
# +------------+---------------------+
# | anyth      | anything            |
# +------------+---------------------+
# | compress   | compressed          |
# +------------+---------------------+
# | suppli     | supply              |
# +------------+---------------------+
# | batteri    | battery             |
# +------------+---------------------+
# | apiec      | apiece              |
# +------------+---------------------+
# | look       | looked              |
# +------------+---------------------+
# | shrug      | shrugged            |
# +------------+---------------------+
# | fatalist   | fatalistically      |
# +------------+---------------------+
# | ani        | any                 |
# +------------+---------------------+
# | as         | a                   |
# +------------+---------------------+

# %% [markdown]
# ### Ex 11
# Print the first N most frequent lemmas (after the removal of stopwords) together with their number of appearances.

# %%
lemmatizer = WordNetLemmatizer()

lemmatized_words = []

for word in tokens:

    lemmatized_word = lemmatizer.lemmatize(word.lower())
    lemmatized_words.append(lemmatized_word)

lemma_word_counts = Counter(words)

N = 10

filtered_word_counts = {word: count for word, count in lemma_word_counts.items() if word not in stopwords_set}

sorted_word_counts = sorted(filtered_word_counts.items(), key=lambda x: x[1], reverse=True)

for lemma, count in sorted_word_counts[:N]:
    print(f"{lemma}: {count}")
# Out:
# project: 85
# gutenberg™: 57
# work: 45
# bradford: 42
# works: 32
# canham: 30
# gutenberg: 28
# electronic: 27
# rodriguez: 25
# foundation: 25

# %% [markdown]
# ### Ex 12
# Change all the numbers from lws into words. Print the number of changes, and also the portion of list that contains first N changes (for example N=10).

# %%
from num2words import num2words

lws_copy = lws.copy()
for i in range(len(lws_copy)):
    try:
        lws_copy[i] = num2words(int(lws_copy[i]))
    except:
        pass

differences = [lws_copy[i] for i in range(len(lws_copy)) if lws_copy[i] != lws[i]]

N = 10
print("Top", N, "differences:")
print(differences[:N])
# Out:
# Top 10 differences:
# ['one thousand, nine hundred and sixty-one', 'one', 'twenty', 'sixty', 'four', 'thirty', 'ninety', 'three', 'ninety', 'two']

# %% [markdown]
# ### Ex 13
# Create a function that receives an integer N and a word W as parameter (it can also receive the list of words from the text). We want to print the concordance data for that word. This means printing the window of text (words on consecutive positions) of length N, that has the givend word W in the middle. For example, for the text ""I have two dogs and a cat. Do you have pets too? My cat likes to chase mice. My dogs like to chase my cat." and a window of length 3, the concordance data for the word "cat" would be ["dogs", "cat", "pets"] and ["pets","cat", "likes"] (we consider the text without stopwords and punctuation). However, as you can see, the window of text may contain words from different sentences. Create a second function that prints windows of texts that contain words only from the phrase containing word W. We want to print concordance data for all the inflexions of word W.

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import string

def get_concordance_data(N, W, text):

    lemmatizer = WordNetLemmatizer()

    tokens = word_tokenize(text)
    
    stop_words = set(stopwords.words('english'))
    tokens = [token.lower() for token in tokens if token.lower() not in stop_words and token not in string.punctuation]
    
    # Find the base form of the target word
    base_W = lemmatizer.lemmatize(W)

    # Find the concordance data for all inflections of word W
    concordance_data = {}
    for i in range(len(tokens)):
        # Find the base form of the current word
        base_word = lemmatizer.lemmatize(tokens[i])

        # If the base form of the current word is the same as the base form of the target word
        if base_word == base_W:
            start_index = max(0, i - N)
            end_index = min(len(tokens), i + N + 1)
            window = tokens[start_index:end_index]

            # If the current word is not already in the concordance data, add it
            if tokens[i] not in concordance_data:
                concordance_data[tokens[i]] = []

            concordance_data[tokens[i]].append(window)
    
    return concordance_data

def get_phrase_concordance_data(N, W, text):

    lemmatizer = WordNetLemmatizer()

    sentences = nltk.sent_tokenize(text)
    
    base_W = lemmatizer.lemmatize(W)

    concordance_data = {}
    for sentence in sentences:
        tokens = word_tokenize(sentence)
        tokens = [token.lower() for token in tokens if token.lower() not in stopwords.words('english') and token not in string.punctuation]
        
        for i in range(len(tokens)):
            # Find the base form of the current word
            base_word = lemmatizer.lemmatize(tokens[i])

            # If the base form of the current word is the same as the base form of the target word
            if base_word == base_W:
                start_index = max(0, i - N)
                end_index = min(len(tokens), i + N + 1)
                window = tokens[start_index:end_index]

                # If the current word is not already in the concordance data, add it
                if tokens[i] not in concordance_data:
                    concordance_data[tokens[i]] = []

                concordance_data[tokens[i]].append(window)
    
    return concordance_data

text = "I have two dogs and a cat. Do you have pets too? My cat likes to chase mice. My dogs like to chase my cat."
N = 3
W = "cat"

concordance_data = get_concordance_data(N, W, text)
print("Concordance data for all inflections of word", W)
for word, windows in concordance_data.items():
    print("\nConcordance data for word", word)
    for window in windows:
        print(window)

phrase_concordance_data = get_phrase_concordance_data(N, W, text)
print("\nPhrase concordance data for all inflections of word", W)
for word, windows in phrase_concordance_data.items():
    print("\nPhrase concordance data for word", word)
    for window in windows:
        print(window)
# Out:
# Concordance data for all inflections of word cat
#
# Concordance data for word cat
# ['two', 'dogs', 'cat', 'pets', 'cat', 'likes']
# ['dogs', 'cat', 'pets', 'cat', 'likes', 'chase', 'mice']
# ['dogs', 'like', 'chase', 'cat']
#
# Phrase concordance data for all inflections of word cat
#
# Phrase concordance data for word cat
# ['two', 'dogs', 'cat']
# ['cat', 'likes', 'chase', 'mice']
# ['dogs', 'like', 'chase', 'cat']
